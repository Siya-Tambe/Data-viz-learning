# %% [markdown]
# <a href="https://colab.research.google.com/github/Siya-Tambe/Data-viz-learning/blob/main/numpy/01_random_number_%26_random_array.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Generating random numbers
import random
num = random.random()
print(num)
# Out:
# 0.4832101164772855

# %%
# Randint() function
import random
print(random.randint(0,9)) # Here range it specified from 0 to 9
# Out:
# 0

# %%
"""Generate Random Array
. In NumPy we work with arrays, and you can use the two methods from the above examples to make
random arrays.
. The randint() method takes a size parameter where you can specify the shape of an array.
. Ex: Generate a 1-D array containing 5 random integers from 0 to 100"""

from numpy import random
random.randint(100, size = (5))

# Here we're generating a 1-D array containing 5 random intergers from 0 to 100
# Out:
# array([42, 90, 82,  1, 69])

# %%
"""random.randrange() Method
. Python provides a function named randrange() in the random package that can produce
random numbers from a given range while still enabling spaces for steps to be included.
. The below example uses randrange() to randomly print integers."""

import random
print("Random integers between 0 and 9: ")
for i in range (4,15):
  y = random.randrange(9)
  print(y)
# Out:
# Random integers between 0 and 9:
# 5
# 0
# 0
# 7
# 3
# 4
# 5
# 5
# 7
# 5
# 3
