# %% [markdown]
# <a href="https://colab.research.google.com/github/Siya-Tambe/Data-viz-learning/blob/main/matplotlib/06_Bar_graph_horizontal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''We can also flip the bar graph horizontally with the following
creating horizontal bar graph'''
# Out:
# 'We can also flip the bar graph horizontally with the following\ncreating horizontal bar graph'

# %%
import matplotlib.pyplot as plt

# %%
#Create data for plotting
values = [5,6,3,7,2]
names = ["A","B","C","D","E"]

# %%
#Adding an "h" after bar will flip the graph
plt.barh(names, values, color="yellowgreen")
plt.show()
