# %% [markdown]
# <a href="https://colab.research.google.com/github/Siya-Tambe/Data-viz-learning/blob/main/matplotlib/01_line_plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
# create data fro plotting
x_values = [0,1,2,3,4,5]
y_values = [0,1,4,9,16,25]

# %%
# the default graph style for plot is a line
plt.plot(x_values,y_values)

# display the graph
plt.show()
