# %% [markdown]
# <a href="https://colab.research.google.com/github/Siya-Tambe/Data-viz-learning/blob/main/matplotlib/03_Simple_2_line_graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# line 1 points
x1 = [1,2,3]
y1 = [2,4,1]

# plotting the line 1 points
plt.plot(x1,y1,label = "line_1")

# line 2 points
x2 = [1,2,3]
y2 = [4,1,3]

# plotting the line 2 points
plt.plot(x2,y2,label = "line_2")

# naming the x & y axis
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

# giving a title to my graph!
plt.title("Tow lines on same graph")

# show legend on the plot
plt.legend()
plt.show()
